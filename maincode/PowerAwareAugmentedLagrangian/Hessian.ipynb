# %%
import torch
import os
import sys
from pathlib import Path
sys.path.append(os.getcwd())
sys.path.append(str(Path(os.getcwd()).parent))
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('../utils/')
from configuration import *
from utils import *
import FigureConfig as FC
import pNN_Power_Aware as pNN

args = parser.parse_args([])

# %%
result = torch.load('result.matrix')
result.shape
# Out:
# torch.Size([10, 4, 13, 12])

# %%
import numpy as np

target = [[ 200.,  240.,  400.,  500.,  300.,  300.,  200.,  300.,  600.,  280.,  340.,  280.,  240.],
          [ 400.,  480.,  800., 1000.,  600.,  600.,  400.,  600., 1200.,  560.,  680.,  560.,  480.],
          [ 600.,  720., 1200., 1500.,  900.,  900.,  600.,  900., 1800.,  840., 1020.,  840.,  720.],
          [ 800.,  960., 1600., 2000., 1200., 1200.,  800., 1200., 2400., 1120., 1360., 1120.,  960.]]
target = np.array(target)

# %%
def calculate_hessian_eigenvalues(model, dataloader, loss_function):
    eigenvalues = {}

    model.train()
    
    for images, labels in dataloader:
        
        # 前向传播
        outputs = model(images)
        loss = loss_function(model, images, labels)
        
        # 计算梯度
        model.zero_grad()
        loss.backward(create_graph=True)
        
        for n, p in model.named_parameters():
            if p.requires_grad:
                grad = p.grad.view(-1)
                hessian = torch.zeros(grad.size(0), grad.size(0))
                # 计算Hessian的每个元素
                for i in range(len(grad)):
                    grad2 = torch.autograd.grad(grad[i], p, retain_graph=True, allow_unused=True)[0].view(-1)
                    if grad2 is not None:
                        hessian[i, :] = grad2
                
                # 计算Hessian的特征值
                eigvals = torch.linalg.eigvals(hessian)
                eigenvalues[n] = eigvals
    
    return eigenvalues

# %%
values = []

for ds in range(13):
    values_ds = []
    
    args.DATASET = ds
    train_loader, datainfo = GetDataLoader(args, 'train', path='../dataset/')
    
    
    print(datainfo)

    
    
    for i in range(4):
        values_target = []
        
        power = result[:,i,ds,3]
        acc = result[:,i,ds,2]

        best_acc = acc.max()
        seed = torch.where(acc == best_acc)[0][0].item()

        
        args.powerbalance = target[i,ds]
        args.POWER = target[i,ds]

        
        setup = f"data_{datainfo['dataname']}_seed_{seed}_Penalty_AL_Factor_{int(args.powerbalance):04d}"
        print(setup)

        model_PT_name = f'./models/pNN_{setup}.model'
        model_PT = torch.load(model_PT_name)
        model_PT.pruning

        args.powerestimator = 'AL'
        args.powerbalance = 0.
        loss_function = pNN.Lossfunction(args)

        # # 计算 Hessian 矩阵的特征值
        eigenvalues = calculate_hessian_eigenvalues(model_PT, train_loader, loss_function)
        
        # # 打印 Hessian 矩阵的特征值
        for n, eigvals in eigenvalues.items():
            # Sort eigenvalues by their absolute values in descending order
            top_eigvals = sorted(eigvals, key=lambda x: abs(x), reverse=True)[:3]
            print(f'Top 3 eigenvalues for Hessian of {n}:')
            for eigval in top_eigvals:
                values_target.append(abs(eigval).item())
                print(abs(eigval))

        values_ds.append(values_target)
    values.append(values_ds)
# Out:
# {'dataname': 'acuteinflammation', 'N_feature': 6, 'N_class': 2, 'N_train': 70, 'N_valid': 23, 'N_test': 25}
# data_acuteinflammation_seed_4_Penalty_AL_Factor_0200
# /home/kit/tm/px3192/.local/lib/python3.9/site-packages/torch/autograd/graph.py:744: UserWarning: Using backward() with create_graph=True will create a reference cycle between the parameter and its gradient which can cause a memory leak. We recommend using autograd.grad when creating the graph to avoid this. If you have to use this function, make sure to reset the .grad fields of your parameters to None after use to break the cycle and avoid the leak. (Triggered internally at ../torch/csrc/autograd/engine.cpp:1203.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0004)
# tensor(8.7321e-07)
# tensor(7.4383e-10)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# data_acuteinflammation_seed_2_Penalty_AL_Factor_0400
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0004)
# tensor(1.4416e-05)
# tensor(7.2291e-09)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# data_acuteinflammation_seed_1_Penalty_AL_Factor_0600
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0015)
# tensor(7.3603e-06)
# tensor(5.0293e-10)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(4.1084e-09)
# tensor(5.5128e-10)
# tensor(4.7619e-10)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.0398)
# tensor(0.0058)
# tensor(7.9464e-05)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.0017)
# tensor(5.3142e-06)
# tensor(1.0792e-07)
# data_acuteinflammation_seed_0_Penalty_AL_Factor_0800
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0008)
# tensor(7.7127e-05)
# tensor(1.8227e-09)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# {'dataname': 'balancescale', 'N_feature': 4, 'N_class': 3, 'N_train': 373, 'N_valid': 124, 'N_test': 126}
# data_balancescale_seed_4_Penalty_AL_Factor_0240
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(5.3234e-07)
# tensor(2.1535e-07)
# tensor(1.2024e-10)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# data_balancescale_seed_0_Penalty_AL_Factor_0480
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0597)
# tensor(0.0064)
# tensor(4.0067e-09)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(8.3168e-05)
# tensor(7.7120e-06)
# tensor(4.6251e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(7108.7979)
# tensor(3294.3503)
# tensor(369.8977)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(84.5786)
# tensor(0.3823)
# tensor(0.)
# data_balancescale_seed_9_Penalty_AL_Factor_0720
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(9.6583e-08)
# tensor(8.6791e-08)
# tensor(3.3274e-08)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(6.3104e-05)
# tensor(5.4650e-05)
# tensor(2.5816e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(53.4780)
# tensor(20.6322)
# tensor(5.6585)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(351.1392)
# tensor(296.3554)
# tensor(2.9176)
# data_balancescale_seed_0_Penalty_AL_Factor_0960
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0001)
# tensor(2.4667e-09)
# tensor(9.1944e-10)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# {'dataname': 'breastcancerwisc', 'N_feature': 9, 'N_class': 2, 'N_train': 418, 'N_valid': 139, 'N_test': 140}
# data_breastcancerwisc_seed_3_Penalty_AL_Factor_0400
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(3.2562e-07)
# tensor(8.5286e-08)
# tensor(1.5797e-08)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(1.2535e-06)
# tensor(4.0768e-07)
# tensor(1.4094e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.0095)
# tensor(0.0003)
# tensor(3.3946e-05)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(3.6089)
# tensor(0.0004)
# tensor(6.7143e-07)
# data_breastcancerwisc_seed_9_Penalty_AL_Factor_0800
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(5.4896e-07)
# tensor(5.1660e-07)
# tensor(2.0547e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0002)
# tensor(4.0901e-07)
# tensor(3.7712e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.0595)
# tensor(0.0047)
# tensor(0.0008)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.0020)
# tensor(7.8750e-06)
# tensor(1.8248e-06)
# data_breastcancerwisc_seed_6_Penalty_AL_Factor_1200
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(8.9832e-08)
# tensor(2.7632e-08)
# tensor(1.6028e-08)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0026)
# tensor(1.2986e-07)
# tensor(4.1992e-08)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.0278)
# tensor(0.0263)
# tensor(0.0123)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.0006)
# tensor(0.0001)
# tensor(7.2066e-05)
# data_breastcancerwisc_seed_0_Penalty_AL_Factor_1600
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0046)
# tensor(0.0005)
# tensor(3.2046e-05)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.1940)
# tensor(7.4092e-06)
# tensor(2.8314e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.2861)
# tensor(0.0106)
# tensor(0.0072)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(3.7901e-05)
# tensor(8.4347e-06)
# tensor(8.0643e-07)
# {'dataname': 'cardiotocography3clases', 'N_feature': 21, 'N_class': 3, 'N_train': 1274, 'N_valid': 424, 'N_test': 426}
# data_cardiotocography3clases_seed_5_Penalty_AL_Factor_0500
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(2.9257)
# tensor(6.2303e-06)
# tensor(2.5323e-06)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.3186)
# tensor(0.0002)
# tensor(0.0001)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(65.0061)
# tensor(18.9596)
# tensor(11.3915)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(100.6823)
# tensor(59.6922)
# tensor(29.2272)
# data_cardiotocography3clases_seed_7_Penalty_AL_Factor_1000
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(5.1253e-05)
# tensor(1.2085e-06)
# tensor(5.5017e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0520)
# tensor(0.0002)
# tensor(9.3518e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(27.5447)
# tensor(22.9058)
# tensor(14.7672)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(79.5383)
# tensor(16.8764)
# tensor(3.8115)
# data_cardiotocography3clases_seed_8_Penalty_AL_Factor_1500
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(50.1444)
# tensor(1.8094e-06)
# tensor(6.8967e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0008)
# tensor(0.0001)
# tensor(6.3080e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(117.9340)
# tensor(98.3345)
# tensor(29.5194)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(844.0684)
# tensor(53.6663)
# tensor(21.4286)
# data_cardiotocography3clases_seed_5_Penalty_AL_Factor_2000
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.3495)
# tensor(5.9383e-05)
# tensor(3.6262e-06)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0132)
# tensor(4.9785e-06)
# tensor(4.9273e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.6442)
# tensor(0.0312)
# tensor(0.0143)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.0209)
# tensor(0.0001)
# tensor(1.7556e-06)
# {'dataname': 'energyy1', 'N_feature': 8, 'N_class': 3, 'N_train': 459, 'N_valid': 153, 'N_test': 154}
# data_energyy1_seed_2_Penalty_AL_Factor_0300
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(37.5708)
# tensor(0.0496)
# tensor(3.5989e-06)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0020)
# tensor(0.0010)
# tensor(0.0003)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(217.9912)
# tensor(42.8309)
# tensor(12.9762)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(88.4128)
# tensor(0.0398)
# tensor(0.0084)
# data_energyy1_seed_3_Penalty_AL_Factor_0600
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(6.5284e-07)
# tensor(2.3015e-07)
# tensor(7.1693e-08)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(2.5665e-06)
# tensor(5.0980e-07)
# tensor(2.9963e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(17.2823)
# tensor(0.4102)
# tensor(0.3318)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(15.1435)
# tensor(4.5945)
# tensor(0.0044)
# data_energyy1_seed_4_Penalty_AL_Factor_0900
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.2984)
# tensor(1.5736e-05)
# tensor(9.7644e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0002)
# tensor(1.8395e-06)
# tensor(3.4082e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(4.1647)
# tensor(0.1667)
# tensor(0.0021)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.0990)
# tensor(0.0627)
# tensor(0.0320)
# data_energyy1_seed_2_Penalty_AL_Factor_1200
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(1002.0190)
# tensor(0.0179)
# tensor(1.6618e-06)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.4263)
# tensor(0.0001)
# tensor(6.0229e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(15690.4307)
# tensor(214.9113)
# tensor(13.2883)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.5886)
# tensor(0.5604)
# tensor(0.0599)
# {'dataname': 'energyy2', 'N_feature': 8, 'N_class': 3, 'N_train': 459, 'N_valid': 153, 'N_test': 154}
# data_energyy2_seed_3_Penalty_AL_Factor_0300
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.6148)
# tensor(3.0927e-07)
# tensor(9.7976e-08)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(1.8896e-06)
# tensor(2.0359e-07)
# tensor(4.8056e-08)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(34.7119)
# tensor(1.5006)
# tensor(0.1277)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(1.1642e-10)
# tensor(0.)
# tensor(0.)
# data_energyy2_seed_9_Penalty_AL_Factor_0600
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(13.8431)
# tensor(0.0033)
# tensor(7.6725e-08)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(1.2916e-05)
# tensor(6.9066e-06)
# tensor(1.9023e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(94.5771)
# tensor(7.7092)
# tensor(1.5174)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(748.3574)
# tensor(0.5879)
# tensor(0.0325)
# data_energyy2_seed_7_Penalty_AL_Factor_0900
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(1.2131)
# tensor(5.3312e-07)
# tensor(3.7489e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0089)
# tensor(1.8300e-06)
# tensor(2.9898e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(9.2321)
# tensor(0.7907)
# tensor(0.4171)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(52.2985)
# tensor(2.7148)
# tensor(0.0008)
# data_energyy2_seed_3_Penalty_AL_Factor_1200
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.7183)
# tensor(2.1583e-06)
# tensor(4.1578e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.5281)
# tensor(7.2081e-05)
# tensor(9.7632e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(1109.7963)
# tensor(29.1081)
# tensor(0.8826)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.1721)
# tensor(0.0485)
# tensor(0.0110)
# {'dataname': 'iris', 'N_feature': 4, 'N_class': 3, 'N_train': 88, 'N_valid': 29, 'N_test': 31}
# data_iris_seed_0_Penalty_AL_Factor_0200
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(8.9261e-07)
# tensor(3.8488e-07)
# tensor(3.1323e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(1.8221e-06)
# tensor(1.5102e-06)
# tensor(2.3734e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(2.0781)
# tensor(0.1055)
# tensor(0.0210)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.0008)
# tensor(9.1482e-05)
# tensor(5.2573e-08)
# data_iris_seed_8_Penalty_AL_Factor_0400
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(1.2147)
# tensor(4.9133e-08)
# tensor(1.8636e-08)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(1.1582e-05)
# tensor(1.0009e-05)
# tensor(3.1984e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(44.8342)
# tensor(0.3147)
# tensor(0.0515)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.5956)
# tensor(0.0725)
# tensor(0.0105)
# data_iris_seed_5_Penalty_AL_Factor_0600
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(5.2106e-06)
# tensor(1.1140e-06)
# tensor(5.1504e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.9964)
# tensor(8.4177e-05)
# tensor(7.0952e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(188.2738)
# tensor(0.0268)
# tensor(0.0061)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(3.6464)
# tensor(0.0714)
# tensor(0.0395)
# data_iris_seed_0_Penalty_AL_Factor_0800
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(1.1916e-05)
# tensor(9.6445e-07)
# tensor(9.5412e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0433)
# tensor(8.9973e-05)
# tensor(4.9701e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(48.0388)
# tensor(0.0115)
# tensor(0.0106)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.0524)
# tensor(4.2008e-06)
# tensor(4.0663e-07)
# {'dataname': 'mammographic', 'N_feature': 5, 'N_class': 2, 'N_train': 575, 'N_valid': 191, 'N_test': 193}
# data_mammographic_seed_1_Penalty_AL_Factor_0300
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0022)
# tensor(0.0004)
# tensor(1.3620e-05)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(6.5315e-05)
# tensor(1.5403e-06)
# tensor(1.2279e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(89.7571)
# tensor(9.2811)
# tensor(2.2507)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(1.9401)
# tensor(0.8932)
# tensor(0.0074)
# data_mammographic_seed_5_Penalty_AL_Factor_0600
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0513)
# tensor(5.7454e-05)
# tensor(9.1596e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0008)
# tensor(5.3167e-07)
# tensor(3.2318e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(7218.6987)
# tensor(723.1772)
# tensor(304.2582)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(47.6693)
# tensor(1.0599)
# tensor(0.0881)
# data_mammographic_seed_6_Penalty_AL_Factor_0900
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.7070)
# tensor(0.0016)
# tensor(0.0003)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(26.9667)
# tensor(0.0006)
# tensor(0.0004)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(828.9265)
# tensor(33.3343)
# tensor(1.8420)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(1.7805)
# tensor(0.5444)
# tensor(0.0004)
# data_mammographic_seed_4_Penalty_AL_Factor_1200
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(15.6211)
# tensor(0.0031)
# tensor(0.0001)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.2212)
# tensor(0.0101)
# tensor(0.0019)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(162.5677)
# tensor(1.8137)
# tensor(0.3420)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.3038)
# tensor(0.0269)
# tensor(0.0026)
# {'dataname': 'Pendigits', 'N_feature': 16, 'N_class': 10, 'N_train': 2198, 'N_valid': 732, 'N_test': 733}
# data_Pendigits_seed_2_Penalty_AL_Factor_0600
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(9.3325e-06)
# tensor(2.1461e-06)
# tensor(4.1519e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0006)
# tensor(2.6147e-06)
# tensor(1.4966e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(12047.7139)
# tensor(334.5328)
# tensor(168.5412)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(1307.2543)
# tensor(909.8171)
# tensor(830.1276)
# data_Pendigits_seed_3_Penalty_AL_Factor_1200
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(1.8063e-06)
# tensor(6.5106e-07)
# tensor(1.9152e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0014)
# tensor(9.0627e-05)
# tensor(8.1250e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(2970.5884)
# tensor(781.4321)
# tensor(351.7532)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(4280.7163)
# tensor(1623.8086)
# tensor(1513.8480)
# data_Pendigits_seed_2_Penalty_AL_Factor_1800
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(8.4557e-05)
# tensor(1.6503e-08)
# tensor(7.7324e-11)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.1089)
# tensor(0.0547)
# tensor(0.0005)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(14638.3057)
# tensor(4012.1331)
# tensor(2140.8782)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(1037.8142)
# tensor(927.1596)
# tensor(571.6423)
# data_Pendigits_seed_6_Penalty_AL_Factor_2400
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(5.9682e-06)
# tensor(3.4953e-09)
# tensor(1.6723e-10)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(8.2926)
# tensor(1.5902)
# tensor(0.0055)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(4041.9041)
# tensor(2100.6267)
# tensor(1177.7466)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(8147.7788)
# tensor(5030.3198)
# tensor(3054.7026)
# {'dataname': 'seeds', 'N_feature': 7, 'N_class': 3, 'N_train': 124, 'N_valid': 41, 'N_test': 43}
# data_seeds_seed_4_Penalty_AL_Factor_0280
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(7.8735e-07)
# tensor(4.4023e-07)
# tensor(3.4148e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(7.8447e-05)
# tensor(2.7475e-05)
# tensor(1.2994e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(2.1321)
# tensor(0.6019)
# tensor(0.1175)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(2533.3828)
# tensor(35.0521)
# tensor(0.0373)
# data_seeds_seed_6_Penalty_AL_Factor_0560
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0005)
# tensor(3.9837e-05)
# tensor(9.0074e-06)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(5.8423)
# tensor(0.0020)
# tensor(5.1607e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(5418.6235)
# tensor(180.4908)
# tensor(4.4049)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(129.6954)
# tensor(32.3754)
# tensor(0.1801)
# data_seeds_seed_2_Penalty_AL_Factor_0840
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(1.4507e-05)
# tensor(6.4759e-06)
# tensor(5.8495e-06)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0002)
# tensor(4.7445e-05)
# tensor(3.4514e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(935.6245)
# tensor(13.5546)
# tensor(4.9803)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(1601.3528)
# tensor(413.2120)
# tensor(39.6022)
# data_seeds_seed_8_Penalty_AL_Factor_1120
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0016)
# tensor(0.0005)
# tensor(5.5910e-05)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0147)
# tensor(7.8734e-07)
# tensor(5.4225e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.9772)
# tensor(0.7029)
# tensor(0.0406)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.4520)
# tensor(0.0192)
# tensor(0.0004)
# {'dataname': 'tictactoe', 'N_feature': 9, 'N_class': 2, 'N_train': 573, 'N_valid': 191, 'N_test': 192}
# data_tictactoe_seed_2_Penalty_AL_Factor_0340
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0206)
# tensor(0.0019)
# tensor(0.0019)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(5.7691e-05)
# tensor(1.9641e-05)
# tensor(1.1661e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(1256.6073)
# tensor(534.4160)
# tensor(493.6109)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(1258.5151)
# tensor(1096.0287)
# tensor(1.0860)
# data_tictactoe_seed_2_Penalty_AL_Factor_0680
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0006)
# tensor(0.0001)
# tensor(4.5531e-05)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(3.4064e-05)
# tensor(5.6978e-06)
# tensor(3.3088e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(306.8342)
# tensor(75.3875)
# tensor(67.7538)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(399.3786)
# tensor(15.6823)
# tensor(0.2187)
# data_tictactoe_seed_6_Penalty_AL_Factor_1020
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(7.0458e-05)
# tensor(2.3933e-07)
# tensor(1.0426e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(2.3292e-08)
# tensor(2.4745e-09)
# tensor(5.4820e-10)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(0.4216)
# tensor(0.0722)
# tensor(0.0588)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.0002)
# tensor(6.2791e-05)
# tensor(3.4818e-05)
# data_tictactoe_seed_7_Penalty_AL_Factor_1360
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(1.9164)
# tensor(2.7789e-06)
# tensor(9.2936e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0072)
# tensor(2.7380e-06)
# tensor(2.4793e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(93.6321)
# tensor(3.7156)
# tensor(0.0144)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.1496)
# tensor(0.0910)
# tensor(3.3343e-05)
# {'dataname': 'vertebralcolumn2clases', 'N_feature': 6, 'N_class': 2, 'N_train': 184, 'N_valid': 61, 'N_test': 63}
# data_vertebralcolumn2clases_seed_8_Penalty_AL_Factor_0280
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0016)
# tensor(0.0004)
# tensor(4.6374e-05)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.)
# tensor(0.)
# tensor(0.)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(4.1956)
# tensor(0.0065)
# tensor(0.0003)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(31.6293)
# tensor(26.4685)
# tensor(0.)
# data_vertebralcolumn2clases_seed_2_Penalty_AL_Factor_0560
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0132)
# tensor(0.0005)
# tensor(3.3776e-05)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.3927)
# tensor(0.0048)
# tensor(2.0969e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(866.4589)
# tensor(189.6074)
# tensor(24.6639)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(53.8759)
# tensor(0.4930)
# tensor(0.0168)
# data_vertebralcolumn2clases_seed_8_Penalty_AL_Factor_0840
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0169)
# tensor(0.0020)
# tensor(0.0006)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(111.4691)
# tensor(0.0068)
# tensor(3.5470e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(2443.8779)
# tensor(714.9838)
# tensor(0.9777)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(933.6212)
# tensor(266.4446)
# tensor(0.7927)
# data_vertebralcolumn2clases_seed_9_Penalty_AL_Factor_1120
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(20.7738)
# tensor(0.0097)
# tensor(0.0005)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(12.4556)
# tensor(0.0035)
# tensor(2.7325e-06)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(229.0281)
# tensor(32.3240)
# tensor(0.9053)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.4227)
# tensor(0.1047)
# tensor(0.0224)
# {'dataname': 'vertebralcolumn3clases', 'N_feature': 6, 'N_class': 3, 'N_train': 184, 'N_valid': 61, 'N_test': 63}
# data_vertebralcolumn3clases_seed_0_Penalty_AL_Factor_0240
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(9.5588e-06)
# tensor(2.8066e-06)
# tensor(1.1798e-06)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0004)
# tensor(6.2718e-07)
# tensor(3.0083e-07)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(33.9627)
# tensor(0.2087)
# tensor(0.0261)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(3165.2251)
# tensor(1729.0212)
# tensor(3.9160)
# data_vertebralcolumn3clases_seed_0_Penalty_AL_Factor_0480
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(0.0001)
# tensor(4.2732e-05)
# tensor(1.4228e-05)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(6.5246e-05)
# tensor(1.1913e-05)
# tensor(1.1894e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(2403.2368)
# tensor(90.1899)
# tensor(21.9510)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(1316.8752)
# tensor(373.3109)
# tensor(10.7650)
# data_vertebralcolumn3clases_seed_0_Penalty_AL_Factor_0720
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(7.1534e-06)
# tensor(2.0786e-07)
# tensor(9.2930e-08)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(0.0002)
# tensor(3.0101e-05)
# tensor(2.2788e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(61.3642)
# tensor(20.5999)
# tensor(0.6017)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(211.1300)
# tensor(149.5784)
# tensor(37.3065)
# data_vertebralcolumn3clases_seed_8_Penalty_AL_Factor_0960
# Top 3 eigenvalues for Hessian of act.rt_:
# tensor(9.4637e-06)
# tensor(1.5173e-06)
# tensor(6.2542e-07)
# Top 3 eigenvalues for Hessian of inv.rt_:
# tensor(4.9880)
# tensor(0.0002)
# tensor(3.9019e-05)
# Top 3 eigenvalues for Hessian of model.0-th pLayer.theta_:
# tensor(63.6528)
# tensor(47.5937)
# tensor(13.4370)
# Top 3 eigenvalues for Hessian of model.1-th pLayer.theta_:
# tensor(0.9979)
# tensor(0.4532)
# tensor(0.1347)

# %%
values = torch.tensor(values)
top_values, top_indices = values.topk(6, dim=-1)

# top_values will have the shape [13, 4, 3]
print("Shape of the resulting tensor:", top_values.shape)
# Out:
# Shape of the resulting tensor: torch.Size([13, 4, 6])

# %%
torch.save(top_values, '../RESULT/al.hessian')
